# %%
import numpy as np
import pandas as pd
import requests
from time import sleep
from bs4 import BeautifulSoup
import re
from dateutil.parser import *
import numpy.random

# %%
filename = 'SinglePlayerGames.csv'

df=pd.read_csv(filename, sep=',',header='infer')
df.values
# Out:
# array([['https://steamdb.info/app/493790/'],
#        ['https://steamdb.info/app/303720/'],
#        ['https://steamdb.info/app/614910/'],
#        ...,
#        ['https://steamdb.info/app/665900/'],
#        ['https://steamdb.info/app/490390/'],
#        ['https://steamdb.info/app/460250/']], dtype=object)

# %%
Links = []
for line in df.values:
    Links.append(line[0])
Links[0:5]
# Out:
# ['https://steamdb.info/app/493790/',
#  'https://steamdb.info/app/303720/',
#  'https://steamdb.info/app/614910/',
#  'https://steamdb.info/app/392190/',
#  'https://steamdb.info/app/557330/']

# %%
url = Links[0]
#url = "https://steamdb.info/app/252950/"
response = requests.get(url)

# %%
html = response.text

# %%
def pullpage(url):
    """download html of each page, and save to disk using Steam ID number"""
    print("trying page at",url)
    response = requests.get(url)
    htmlstring = response.text
    soup = BeautifulSoup(htmlstring,"lxml")
    
    ID_num = soup.find(class_="table table-bordered table-hover table-dark")\
        .findNext("td").findNext("td").text
    Name = soup.find(itemprop="name").text
    
    filename = "/Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/"+\
                    "SteamGameID"+str(ID_num)+".html"
    file = open(filename,'w') 
    file.write(htmlstring) 
    file.close()
    print("saved",Name,"page to",filename)

# %%
pullpage(url)
# Out:
# trying page at https://steamdb.info/app/493790/
# saved #Archery page to /Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/SteamGameID493790.html

# %%
for game in Links:
    pullpage(game)
    delay = 3*np.random.random()+1
    sleep(delay)
print()
print('Mission Accomplished!')
# Out:
# trying page at https://steamdb.info/app/493790/
# saved #Archery page to /Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/SteamGameID493790.html
# trying page at https://steamdb.info/app/303720/
# saved #killallzombies page to /Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/SteamGameID303720.html
# trying page at https://steamdb.info/app/614910/
# saved #monstercakes page to /Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/SteamGameID614910.html
# trying page at https://steamdb.info/app/392190/
# saved #SelfieTennis page to /Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/SteamGameID392190.html
# trying page at https://steamdb.info/app/557330/
# saved >//:System.Hack page to /Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/SteamGameID557330.html
# trying page at https://steamdb.info/app/562280/
# saved </reality> page to /Users/dlicht/ds/metis/metisgh/projects/projectluther/Data/SteamGameID562280.html
# ...

# %%
3*np.random.random()+1

# %%
#Note:  one page around 1985-8 had a timeout error

# %%
#error again on SteamGameID566050
seemed ok on second try
#Links[4950:4999]
# Out:
#   File "<ipython-input-20-c853da9ef9af>", line 2
#     seemed ok on second try
#             ^
# SyntaxError: invalid syntax
